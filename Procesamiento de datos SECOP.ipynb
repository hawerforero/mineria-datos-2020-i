# %%
import pandas as pd

# %%
# Carga el fichero 
df = pd.read_csv('data/secopi_2015.csv', engine="python")
df
# Out:
#         NUMERO DE CONSTANCIA     NUMERO DEL PROCESO  \
# 0              15-12-4432720                 3283-3
# 1              15-13-4439035             IP-126-015
# 2              15-13-4439102            SA-020-2015
# 3              15-13-4439319     IP-DT-SEI-006-2015
# 4              15-12-4439290  ESCRITURA 855 DE 2012
# ...                      ...                    ...
# 1044726         15-4-3269982                 187-14
# 1044727         15-4-3269981                 186-14
# 1044728         15-4-3269979                 184-14
# 1044729        15-12-3269978            CD-108-2014
# 1044730        15-12-3269977            CD-092-2014
#
#                                  TIPO DE PROCESO  \
# 0        Contrataci�n Directa (Ley 1150 de 2007)
# 1                    Contrataci�n M�nima Cuant�a
# 2                    Contrataci�n M�nima Cuant�a
# 3                    Contrataci�n M�nima Cuant�a
# 4        Contrataci�n Directa (Ley 1150 de 2007)
# ...

# %%
print(df.describe(include="all"))
# Out:
#        NUMERO DE CONSTANCIA                 NUMERO DEL PROCESO  \
# count               1044731                            1044584
# unique              1030160                             672182
# top            15-4-3835792  SOLICITUD INFORMAL DE COTIZACION
# freq                    170                               3993
# mean                    NaN                                NaN
# std                     NaN                                NaN
# min                     NaN                                NaN
# 25%                     NaN                                NaN
# 50%                     NaN                                NaN
# 75%                     NaN                                NaN
# max                     NaN                                NaN
#
#                                 TIPO DE PROCESO  \
# count                                   1044731
# unique                                       12
# top     Contrataci�n Directa (Ley 1150 de 2007)
# ...

# %%
df.drop(columns=['NUMERO DEL PROCESO',
                'TIPO DE PROCESO',
                'NUMERO DEL CONTRATO',
                'OBJETO DEL CONTRATO', 
                'ID DEL CONTRATISTA',
                'NOMBRE CONTRATISTA',
                'FECHA  FIRMA CONTRAT',
                'DESCRIPCION'])
# Out:
#         NUMERO DE CONSTANCIA  \
# 0              15-12-4432720
# 1              15-13-4439035
# 2              15-13-4439102
# 3              15-13-4439319
# 4              15-12-4439290
# ...                      ...
# 1044726         15-4-3269982
# 1044727         15-4-3269981
# 1044728         15-4-3269979
# 1044729        15-12-3269978
# 1044730        15-12-3269977
#
#                                       NOMBRE DE LA ENTIDAD  \
# 0        BOL�VAR - ALCALD�A DEL DISTRITO TUR�STICO Y CU...
# 1           RISARALDA - ALCALD�A MUNICIPIO DE DOSQUEBRADAS
# 2              CUNDINAMARCA - ALCALD�A MUNICIPIO DE SIBAT�
# 3                      INSTITUTO NACIONAL DE V�AS (INVIAS)
# 4                   HUILA - ALCALD�A MUNICIPIO DE PITALITO
# ...                                                    ...
# 1044726  BOL�VAR - E.S.E. HOSPITAL LOCAL CARTAGENA DE I...
# 1044727  BOL�VAR - E.S.E. HOSPITAL LOCAL CARTAGENA DE I...
# 1044728  BOL�VAR - E.S.E. HOSPITAL LOCAL CARTAGENA DE I...
# ...
